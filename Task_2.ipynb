# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhiya-git-hub/AI-Tasks/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
RANDOM_STATE = 44

# %%
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
data = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])

# %%
data['label_num'] = data['label'].map({'ham': 0, 'spam': 1})

# %%
TARGET_N = 2000
if len(data) < TARGET_N:
    raise ValueError(f"Dataset has only {len(data)} messages — need at least {TARGET_N}.")

# %%
prop = data['label'].value_counts(normalize=True)
n_spam = int(round(prop['spam'] * TARGET_N))
n_ham = TARGET_N - n_spam
sampled_spam = data[data['label']=='spam'].sample(n=n_spam, random_state=RANDOM_STATE)
sampled_ham  = data[data['label']=='ham'].sample(n=n_ham, random_state=RANDOM_STATE)
sampled = pd.concat([sampled_ham, sampled_spam]).sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)

# %%
X = sampled['message']
y = sampled['label_num']
X_rest, X_test, y_rest, y_test = train_test_split(X, y, test_size=500, stratify=y, random_state=RANDOM_STATE)
X_train, y_train = X_rest, y_rest

# %%
print("Train size:", len(X_train), "Test size:", len(X_test))
print("Spam ratio in train:", y_train.mean(), " Spam ratio in test:", y_test.mean())
# Out:
# Train size: 1500 Test size: 500
# Spam ratio in train: 0.134  Spam ratio in test: 0.134

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=3000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf  = tfidf.transform(X_test)

# %%
model = LogisticRegression(max_iter=2000, random_state=RANDOM_STATE)
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=44)

# %%
LogisticRegression(max_iter=2000, random_state=44)
# Out:
# LogisticRegression(max_iter=2000, random_state=44)

# %%
y_pred = model.predict(X_test_tfidf)
acc = accuracy_score(y_test, y_pred)
print("\nModel Accuracy:", acc)
# Out:
# Model Accuracy: 0.916

# %%
print("\nCategories: ['Not Spam', 'Spam']\n")
sample_messages = X_test.reset_index(drop=True)[:400]
sample_vectors = tfidf.transform(sample_messages)
probabilities = model.predict_proba(sample_vectors)
# Out:
# Categories: ['Not Spam', 'Spam']

# %%
for i, prob in enumerate(probabilities, start=1):
    spam_prob = prob[1]
    prediction = "SPAM" if spam_prob > 0.5 else "NOT SPAM"
    print(f"Email {i}: Sigmoid Output = {spam_prob:.4f} ({spam_prob*100:.1f}%) -> Prediction: {prediction}")
# Out:
# Email 1: Sigmoid Output = 0.0685 (6.9%) -> Prediction: NOT SPAM
# Email 2: Sigmoid Output = 0.0779 (7.8%) -> Prediction: NOT SPAM
# Email 3: Sigmoid Output = 0.0510 (5.1%) -> Prediction: NOT SPAM
# Email 4: Sigmoid Output = 0.0758 (7.6%) -> Prediction: NOT SPAM
# Email 5: Sigmoid Output = 0.0734 (7.3%) -> Prediction: NOT SPAM
# Email 6: Sigmoid Output = 0.0381 (3.8%) -> Prediction: NOT SPAM
# Email 7: Sigmoid Output = 0.1679 (16.8%) -> Prediction: NOT SPAM
# Email 8: Sigmoid Output = 0.0775 (7.7%) -> Prediction: NOT SPAM
# Email 9: Sigmoid Output = 0.0520 (5.2%) -> Prediction: NOT SPAM
# Email 10: Sigmoid Output = 0.0953 (9.5%) -> Prediction: NOT SPAM
# Email 11: Sigmoid Output = 0.0758 (7.6%) -> Prediction: NOT SPAM
# Email 12: Sigmoid Output = 0.0451 (4.5%) -> Prediction: NOT SPAM
# Email 13: Sigmoid Output = 0.0607 (6.1%) -> Prediction: NOT SPAM
# Email 14: Sigmoid Output = 0.0520 (5.2%) -> Prediction: NOT SPAM
# Email 15: Sigmoid Output = 0.0600 (6.0%) -> Prediction: NOT SPAM
# Email 16: Sigmoid Output = 0.0290 (2.9%) -> Prediction: NOT SPAM
# Email 17: Sigmoid Output = 0.4894 (48.9%) -> Prediction: NOT SPAM
# Email 18: Sigmoid Output = 0.8458 (84.6%) -> Prediction: SPAM
# Email 19: Sigmoid Output = 0.4899 (49.0%) -> Prediction: NOT SPAM
# Email 20: Sigmoid Output = 0.0831 (8.3%) -> Prediction: NOT SPAM
# Email 21: Sigmoid Output = 0.0633 (6.3%) -> Prediction: NOT SPAM
# Email 22: Sigmoid Output = 0.0818 (8.2%) -> Prediction: NOT SPAM
# Email 23: Sigmoid Output = 0.1095 (11.0%) -> Prediction: NOT SPAM
# Email 24: Sigmoid Output = 0.0402 (4.0%) -> Prediction: NOT SPAM
# Email 25: Sigmoid Output = 0.0694 (6.9%) -> Prediction: NOT SPAM
# Email 26: Sigmoid Output = 0.0631 (6.3%) -> Prediction: NOT SPAM
# Email 27: Sigmoid Output = 0.0512 (5.1%) -> Prediction: NOT SPAM
# Email 28: Sigmoid Output = 0.1233 (12.3%) -> Prediction: NOT SPAM
# Email 29: Sigmoid Output = 0.1234 (12.3%) -> Prediction: NOT SPAM
# Email 30: Sigmoid Output = 0.7269 (72.7%) -> Prediction: SPAM
# Email 31: Sigmoid Output = 0.0639 (6.4%) -> Prediction: NOT SPAM
# Email 32: Sigmoid Output = 0.0700 (7.0%) -> Prediction: NOT SPAM
# Email 33: Sigmoid Output = 0.7380 (73.8%) -> Prediction: SPAM
# Email 34: Sigmoid Output = 0.0543 (5.4%) -> Prediction: NOT SPAM
# Email 35: Sigmoid Output = 0.0507 (5.1%) -> Prediction: NOT SPAM
# Email 36: Sigmoid Output = 0.1176 (11.8%) -> Prediction: NOT SPAM
# Email 37: Sigmoid Output = 0.0636 (6.4%) -> Prediction: NOT SPAM
# Email 38: Sigmoid Output = 0.0881 (8.8%) -> Prediction: NOT SPAM
# Email 39: Sigmoid Output = 0.0926 (9.3%) -> Prediction: NOT SPAM
# Email 40: Sigmoid Output = 0.0807 (8.1%) -> Prediction: NOT SPAM
# Email 41: Sigmoid Output = 0.0600 (6.0%) -> Prediction: NOT SPAM
# Email 42: Sigmoid Output = 0.0455 (4.5%) -> Prediction: NOT SPAM
# Email 43: Sigmoid Output = 0.0470 (4.7%) -> Prediction: NOT SPAM
# Email 44: Sigmoid Output = 0.0629 (6.3%) -> Prediction: NOT SPAM
# Email 45: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 46: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 47: Sigmoid Output = 0.7749 (77.5%) -> Prediction: SPAM
# Email 48: Sigmoid Output = 0.3857 (38.6%) -> Prediction: NOT SPAM
# Email 49: Sigmoid Output = 0.2208 (22.1%) -> Prediction: NOT SPAM
# Email 50: Sigmoid Output = 0.0532 (5.3%) -> Prediction: NOT SPAM
# Email 51: Sigmoid Output = 0.0705 (7.1%) -> Prediction: NOT SPAM
# Email 52: Sigmoid Output = 0.0788 (7.9%) -> Prediction: NOT SPAM
# Email 53: Sigmoid Output = 0.0687 (6.9%) -> Prediction: NOT SPAM
# Email 54: Sigmoid Output = 0.0435 (4.3%) -> Prediction: NOT SPAM
# Email 55: Sigmoid Output = 0.0615 (6.2%) -> Prediction: NOT SPAM
# Email 56: Sigmoid Output = 0.0357 (3.6%) -> Prediction: NOT SPAM
# Email 57: Sigmoid Output = 0.0722 (7.2%) -> Prediction: NOT SPAM
# Email 58: Sigmoid Output = 0.3123 (31.2%) -> Prediction: NOT SPAM
# Email 59: Sigmoid Output = 0.0869 (8.7%) -> Prediction: NOT SPAM
# Email 60: Sigmoid Output = 0.0854 (8.5%) -> Prediction: NOT SPAM
# Email 61: Sigmoid Output = 0.0705 (7.0%) -> Prediction: NOT SPAM
# Email 62: Sigmoid Output = 0.0840 (8.4%) -> Prediction: NOT SPAM
# Email 63: Sigmoid Output = 0.4865 (48.6%) -> Prediction: NOT SPAM
# Email 64: Sigmoid Output = 0.4210 (42.1%) -> Prediction: NOT SPAM
# Email 65: Sigmoid Output = 0.1090 (10.9%) -> Prediction: NOT SPAM
# Email 66: Sigmoid Output = 0.0547 (5.5%) -> Prediction: NOT SPAM
# Email 67: Sigmoid Output = 0.0506 (5.1%) -> Prediction: NOT SPAM
# Email 68: Sigmoid Output = 0.0309 (3.1%) -> Prediction: NOT SPAM
# Email 69: Sigmoid Output = 0.2699 (27.0%) -> Prediction: NOT SPAM
# Email 70: Sigmoid Output = 0.0499 (5.0%) -> Prediction: NOT SPAM
# Email 71: Sigmoid Output = 0.0349 (3.5%) -> Prediction: NOT SPAM
# Email 72: Sigmoid Output = 0.1218 (12.2%) -> Prediction: NOT SPAM
# Email 73: Sigmoid Output = 0.0781 (7.8%) -> Prediction: NOT SPAM
# Email 74: Sigmoid Output = 0.0632 (6.3%) -> Prediction: NOT SPAM
# Email 75: Sigmoid Output = 0.1073 (10.7%) -> Prediction: NOT SPAM
# Email 76: Sigmoid Output = 0.0948 (9.5%) -> Prediction: NOT SPAM
# Email 77: Sigmoid Output = 0.0517 (5.2%) -> Prediction: NOT SPAM
# Email 78: Sigmoid Output = 0.0618 (6.2%) -> Prediction: NOT SPAM
# Email 79: Sigmoid Output = 0.0602 (6.0%) -> Prediction: NOT SPAM
# Email 80: Sigmoid Output = 0.0520 (5.2%) -> Prediction: NOT SPAM
# Email 81: Sigmoid Output = 0.0451 (4.5%) -> Prediction: NOT SPAM
# Email 82: Sigmoid Output = 0.0788 (7.9%) -> Prediction: NOT SPAM
# Email 83: Sigmoid Output = 0.0928 (9.3%) -> Prediction: NOT SPAM
# Email 84: Sigmoid Output = 0.0594 (5.9%) -> Prediction: NOT SPAM
# Email 85: Sigmoid Output = 0.0633 (6.3%) -> Prediction: NOT SPAM
# Email 86: Sigmoid Output = 0.1477 (14.8%) -> Prediction: NOT SPAM
# Email 87: Sigmoid Output = 0.0960 (9.6%) -> Prediction: NOT SPAM
# Email 88: Sigmoid Output = 0.0449 (4.5%) -> Prediction: NOT SPAM
# Email 89: Sigmoid Output = 0.0695 (6.9%) -> Prediction: NOT SPAM
# Email 90: Sigmoid Output = 0.0684 (6.8%) -> Prediction: NOT SPAM
# Email 91: Sigmoid Output = 0.0456 (4.6%) -> Prediction: NOT SPAM
# Email 92: Sigmoid Output = 0.0703 (7.0%) -> Prediction: NOT SPAM
# Email 93: Sigmoid Output = 0.0676 (6.8%) -> Prediction: NOT SPAM
# Email 94: Sigmoid Output = 0.0871 (8.7%) -> Prediction: NOT SPAM
# Email 95: Sigmoid Output = 0.0986 (9.9%) -> Prediction: NOT SPAM
# Email 96: Sigmoid Output = 0.0840 (8.4%) -> Prediction: NOT SPAM
# Email 97: Sigmoid Output = 0.0796 (8.0%) -> Prediction: NOT SPAM
# Email 98: Sigmoid Output = 0.0901 (9.0%) -> Prediction: NOT SPAM
# Email 99: Sigmoid Output = 0.1030 (10.3%) -> Prediction: NOT SPAM
# Email 100: Sigmoid Output = 0.0566 (5.7%) -> Prediction: NOT SPAM
# Email 101: Sigmoid Output = 0.0615 (6.2%) -> Prediction: NOT SPAM
# Email 102: Sigmoid Output = 0.0579 (5.8%) -> Prediction: NOT SPAM
# Email 103: Sigmoid Output = 0.0815 (8.2%) -> Prediction: NOT SPAM
# Email 104: Sigmoid Output = 0.0621 (6.2%) -> Prediction: NOT SPAM
# Email 105: Sigmoid Output = 0.0694 (6.9%) -> Prediction: NOT SPAM
# Email 106: Sigmoid Output = 0.0477 (4.8%) -> Prediction: NOT SPAM
# Email 107: Sigmoid Output = 0.0585 (5.9%) -> Prediction: NOT SPAM
# Email 108: Sigmoid Output = 0.1210 (12.1%) -> Prediction: NOT SPAM
# Email 109: Sigmoid Output = 0.0688 (6.9%) -> Prediction: NOT SPAM
# Email 110: Sigmoid Output = 0.2470 (24.7%) -> Prediction: NOT SPAM
# Email 111: Sigmoid Output = 0.4724 (47.2%) -> Prediction: NOT SPAM
# Email 112: Sigmoid Output = 0.0393 (3.9%) -> Prediction: NOT SPAM
# Email 113: Sigmoid Output = 0.0708 (7.1%) -> Prediction: NOT SPAM
# Email 114: Sigmoid Output = 0.0608 (6.1%) -> Prediction: NOT SPAM
# Email 115: Sigmoid Output = 0.0818 (8.2%) -> Prediction: NOT SPAM
# Email 116: Sigmoid Output = 0.2433 (24.3%) -> Prediction: NOT SPAM
# Email 117: Sigmoid Output = 0.0569 (5.7%) -> Prediction: NOT SPAM
# Email 118: Sigmoid Output = 0.0765 (7.7%) -> Prediction: NOT SPAM
# Email 119: Sigmoid Output = 0.0608 (6.1%) -> Prediction: NOT SPAM
# Email 120: Sigmoid Output = 0.1076 (10.8%) -> Prediction: NOT SPAM
# Email 121: Sigmoid Output = 0.0637 (6.4%) -> Prediction: NOT SPAM
# Email 122: Sigmoid Output = 0.1117 (11.2%) -> Prediction: NOT SPAM
# Email 123: Sigmoid Output = 0.0393 (3.9%) -> Prediction: NOT SPAM
# Email 124: Sigmoid Output = 0.0568 (5.7%) -> Prediction: NOT SPAM
# Email 125: Sigmoid Output = 0.1186 (11.9%) -> Prediction: NOT SPAM
# Email 126: Sigmoid Output = 0.0481 (4.8%) -> Prediction: NOT SPAM
# Email 127: Sigmoid Output = 0.1254 (12.5%) -> Prediction: NOT SPAM
# Email 128: Sigmoid Output = 0.0870 (8.7%) -> Prediction: NOT SPAM
# Email 129: Sigmoid Output = 0.0258 (2.6%) -> Prediction: NOT SPAM
# Email 130: Sigmoid Output = 0.0442 (4.4%) -> Prediction: NOT SPAM
# Email 131: Sigmoid Output = 0.4551 (45.5%) -> Prediction: NOT SPAM
# Email 132: Sigmoid Output = 0.0953 (9.5%) -> Prediction: NOT SPAM
# Email 133: Sigmoid Output = 0.0775 (7.7%) -> Prediction: NOT SPAM
# Email 134: Sigmoid Output = 0.0777 (7.8%) -> Prediction: NOT SPAM
# Email 135: Sigmoid Output = 0.0598 (6.0%) -> Prediction: NOT SPAM
# Email 136: Sigmoid Output = 0.0534 (5.3%) -> Prediction: NOT SPAM
# Email 137: Sigmoid Output = 0.0321 (3.2%) -> Prediction: NOT SPAM
# Email 138: Sigmoid Output = 0.0601 (6.0%) -> Prediction: NOT SPAM
# Email 139: Sigmoid Output = 0.0390 (3.9%) -> Prediction: NOT SPAM
# Email 140: Sigmoid Output = 0.0986 (9.9%) -> Prediction: NOT SPAM
# Email 141: Sigmoid Output = 0.0373 (3.7%) -> Prediction: NOT SPAM
# Email 142: Sigmoid Output = 0.0478 (4.8%) -> Prediction: NOT SPAM
# Email 143: Sigmoid Output = 0.0750 (7.5%) -> Prediction: NOT SPAM
# Email 144: Sigmoid Output = 0.0467 (4.7%) -> Prediction: NOT SPAM
# Email 145: Sigmoid Output = 0.0821 (8.2%) -> Prediction: NOT SPAM
# Email 146: Sigmoid Output = 0.3101 (31.0%) -> Prediction: NOT SPAM
# Email 147: Sigmoid Output = 0.0989 (9.9%) -> Prediction: NOT SPAM
# Email 148: Sigmoid Output = 0.6540 (65.4%) -> Prediction: SPAM
# Email 149: Sigmoid Output = 0.0563 (5.6%) -> Prediction: NOT SPAM
# Email 150: Sigmoid Output = 0.0906 (9.1%) -> Prediction: NOT SPAM
# Email 151: Sigmoid Output = 0.0656 (6.6%) -> Prediction: NOT SPAM
# Email 152: Sigmoid Output = 0.0489 (4.9%) -> Prediction: NOT SPAM
# Email 153: Sigmoid Output = 0.0365 (3.6%) -> Prediction: NOT SPAM
# Email 154: Sigmoid Output = 0.0693 (6.9%) -> Prediction: NOT SPAM
# Email 155: Sigmoid Output = 0.0874 (8.7%) -> Prediction: NOT SPAM
# Email 156: Sigmoid Output = 0.1081 (10.8%) -> Prediction: NOT SPAM
# Email 157: Sigmoid Output = 0.4977 (49.8%) -> Prediction: NOT SPAM
# Email 158: Sigmoid Output = 0.0556 (5.6%) -> Prediction: NOT SPAM
# Email 159: Sigmoid Output = 0.0705 (7.1%) -> Prediction: NOT SPAM
# Email 160: Sigmoid Output = 0.0631 (6.3%) -> Prediction: NOT SPAM
# Email 161: Sigmoid Output = 0.0848 (8.5%) -> Prediction: NOT SPAM
# Email 162: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 163: Sigmoid Output = 0.0603 (6.0%) -> Prediction: NOT SPAM
# Email 164: Sigmoid Output = 0.0761 (7.6%) -> Prediction: NOT SPAM
# Email 165: Sigmoid Output = 0.0242 (2.4%) -> Prediction: NOT SPAM
# Email 166: Sigmoid Output = 0.0516 (5.2%) -> Prediction: NOT SPAM
# Email 167: Sigmoid Output = 0.1103 (11.0%) -> Prediction: NOT SPAM
# Email 168: Sigmoid Output = 0.0381 (3.8%) -> Prediction: NOT SPAM
# Email 169: Sigmoid Output = 0.0370 (3.7%) -> Prediction: NOT SPAM
# Email 170: Sigmoid Output = 0.0604 (6.0%) -> Prediction: NOT SPAM
# Email 171: Sigmoid Output = 0.0314 (3.1%) -> Prediction: NOT SPAM
# Email 172: Sigmoid Output = 0.0531 (5.3%) -> Prediction: NOT SPAM
# Email 173: Sigmoid Output = 0.0953 (9.5%) -> Prediction: NOT SPAM
# Email 174: Sigmoid Output = 0.0604 (6.0%) -> Prediction: NOT SPAM
# Email 175: Sigmoid Output = 0.0816 (8.2%) -> Prediction: NOT SPAM
# Email 176: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 177: Sigmoid Output = 0.0823 (8.2%) -> Prediction: NOT SPAM
# Email 178: Sigmoid Output = 0.6668 (66.7%) -> Prediction: SPAM
# Email 179: Sigmoid Output = 0.0575 (5.7%) -> Prediction: NOT SPAM
# Email 180: Sigmoid Output = 0.4210 (42.1%) -> Prediction: NOT SPAM
# Email 181: Sigmoid Output = 0.0559 (5.6%) -> Prediction: NOT SPAM
# Email 182: Sigmoid Output = 0.0980 (9.8%) -> Prediction: NOT SPAM
# Email 183: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 184: Sigmoid Output = 0.0851 (8.5%) -> Prediction: NOT SPAM
# Email 185: Sigmoid Output = 0.8068 (80.7%) -> Prediction: SPAM
# Email 186: Sigmoid Output = 0.0583 (5.8%) -> Prediction: NOT SPAM
# Email 187: Sigmoid Output = 0.0811 (8.1%) -> Prediction: NOT SPAM
# Email 188: Sigmoid Output = 0.0238 (2.4%) -> Prediction: NOT SPAM
# Email 189: Sigmoid Output = 0.6280 (62.8%) -> Prediction: SPAM
# Email 190: Sigmoid Output = 0.0856 (8.6%) -> Prediction: NOT SPAM
# Email 191: Sigmoid Output = 0.0736 (7.4%) -> Prediction: NOT SPAM
# Email 192: Sigmoid Output = 0.0505 (5.1%) -> Prediction: NOT SPAM
# Email 193: Sigmoid Output = 0.0849 (8.5%) -> Prediction: NOT SPAM
# Email 194: Sigmoid Output = 0.1024 (10.2%) -> Prediction: NOT SPAM
# Email 195: Sigmoid Output = 0.0609 (6.1%) -> Prediction: NOT SPAM
# Email 196: Sigmoid Output = 0.0818 (8.2%) -> Prediction: NOT SPAM
# Email 197: Sigmoid Output = 0.0797 (8.0%) -> Prediction: NOT SPAM
# Email 198: Sigmoid Output = 0.0495 (4.9%) -> Prediction: NOT SPAM
# Email 199: Sigmoid Output = 0.0627 (6.3%) -> Prediction: NOT SPAM
# Email 200: Sigmoid Output = 0.0712 (7.1%) -> Prediction: NOT SPAM
# Email 201: Sigmoid Output = 0.0464 (4.6%) -> Prediction: NOT SPAM
# Email 202: Sigmoid Output = 0.0534 (5.3%) -> Prediction: NOT SPAM
# Email 203: Sigmoid Output = 0.0581 (5.8%) -> Prediction: NOT SPAM
# Email 204: Sigmoid Output = 0.1064 (10.6%) -> Prediction: NOT SPAM
# Email 205: Sigmoid Output = 0.0700 (7.0%) -> Prediction: NOT SPAM
# Email 206: Sigmoid Output = 0.0362 (3.6%) -> Prediction: NOT SPAM
# Email 207: Sigmoid Output = 0.0813 (8.1%) -> Prediction: NOT SPAM
# Email 208: Sigmoid Output = 0.0702 (7.0%) -> Prediction: NOT SPAM
# Email 209: Sigmoid Output = 0.7830 (78.3%) -> Prediction: SPAM
# Email 210: Sigmoid Output = 0.0789 (7.9%) -> Prediction: NOT SPAM
# Email 211: Sigmoid Output = 0.0567 (5.7%) -> Prediction: NOT SPAM
# Email 212: Sigmoid Output = 0.0517 (5.2%) -> Prediction: NOT SPAM
# Email 213: Sigmoid Output = 0.0790 (7.9%) -> Prediction: NOT SPAM
# Email 214: Sigmoid Output = 0.0646 (6.5%) -> Prediction: NOT SPAM
# Email 215: Sigmoid Output = 0.1783 (17.8%) -> Prediction: NOT SPAM
# Email 216: Sigmoid Output = 0.0592 (5.9%) -> Prediction: NOT SPAM
# Email 217: Sigmoid Output = 0.0677 (6.8%) -> Prediction: NOT SPAM
# Email 218: Sigmoid Output = 0.1145 (11.5%) -> Prediction: NOT SPAM
# Email 219: Sigmoid Output = 0.0565 (5.7%) -> Prediction: NOT SPAM
# Email 220: Sigmoid Output = 0.0560 (5.6%) -> Prediction: NOT SPAM
# Email 221: Sigmoid Output = 0.4848 (48.5%) -> Prediction: NOT SPAM
# Email 222: Sigmoid Output = 0.0809 (8.1%) -> Prediction: NOT SPAM
# Email 223: Sigmoid Output = 0.0860 (8.6%) -> Prediction: NOT SPAM
# Email 224: Sigmoid Output = 0.0628 (6.3%) -> Prediction: NOT SPAM
# Email 225: Sigmoid Output = 0.0782 (7.8%) -> Prediction: NOT SPAM
# Email 226: Sigmoid Output = 0.0996 (10.0%) -> Prediction: NOT SPAM
# Email 227: Sigmoid Output = 0.0802 (8.0%) -> Prediction: NOT SPAM
# Email 228: Sigmoid Output = 0.0769 (7.7%) -> Prediction: NOT SPAM
# Email 229: Sigmoid Output = 0.0702 (7.0%) -> Prediction: NOT SPAM
# Email 230: Sigmoid Output = 0.0543 (5.4%) -> Prediction: NOT SPAM
# Email 231: Sigmoid Output = 0.1645 (16.5%) -> Prediction: NOT SPAM
# Email 232: Sigmoid Output = 0.0600 (6.0%) -> Prediction: NOT SPAM
# Email 233: Sigmoid Output = 0.1253 (12.5%) -> Prediction: NOT SPAM
# Email 234: Sigmoid Output = 0.0746 (7.5%) -> Prediction: NOT SPAM
# Email 235: Sigmoid Output = 0.0503 (5.0%) -> Prediction: NOT SPAM
# Email 236: Sigmoid Output = 0.4796 (48.0%) -> Prediction: NOT SPAM
# Email 237: Sigmoid Output = 0.0517 (5.2%) -> Prediction: NOT SPAM
# Email 238: Sigmoid Output = 0.0545 (5.5%) -> Prediction: NOT SPAM
# Email 239: Sigmoid Output = 0.0646 (6.5%) -> Prediction: NOT SPAM
# Email 240: Sigmoid Output = 0.0752 (7.5%) -> Prediction: NOT SPAM
# Email 241: Sigmoid Output = 0.0863 (8.6%) -> Prediction: NOT SPAM
# Email 242: Sigmoid Output = 0.1287 (12.9%) -> Prediction: NOT SPAM
# Email 243: Sigmoid Output = 0.0842 (8.4%) -> Prediction: NOT SPAM
# Email 244: Sigmoid Output = 0.1045 (10.4%) -> Prediction: NOT SPAM
# Email 245: Sigmoid Output = 0.0693 (6.9%) -> Prediction: NOT SPAM
# Email 246: Sigmoid Output = 0.0689 (6.9%) -> Prediction: NOT SPAM
# Email 247: Sigmoid Output = 0.1198 (12.0%) -> Prediction: NOT SPAM
# Email 248: Sigmoid Output = 0.0884 (8.8%) -> Prediction: NOT SPAM
# Email 249: Sigmoid Output = 0.0651 (6.5%) -> Prediction: NOT SPAM
# Email 250: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 251: Sigmoid Output = 0.0440 (4.4%) -> Prediction: NOT SPAM
# Email 252: Sigmoid Output = 0.0928 (9.3%) -> Prediction: NOT SPAM
# Email 253: Sigmoid Output = 0.2584 (25.8%) -> Prediction: NOT SPAM
# Email 254: Sigmoid Output = 0.0760 (7.6%) -> Prediction: NOT SPAM
# Email 255: Sigmoid Output = 0.2433 (24.3%) -> Prediction: NOT SPAM
# Email 256: Sigmoid Output = 0.0726 (7.3%) -> Prediction: NOT SPAM
# Email 257: Sigmoid Output = 0.1504 (15.0%) -> Prediction: NOT SPAM
# Email 258: Sigmoid Output = 0.2089 (20.9%) -> Prediction: NOT SPAM
# Email 259: Sigmoid Output = 0.0339 (3.4%) -> Prediction: NOT SPAM
# Email 260: Sigmoid Output = 0.0776 (7.8%) -> Prediction: NOT SPAM
# Email 261: Sigmoid Output = 0.0667 (6.7%) -> Prediction: NOT SPAM
# Email 262: Sigmoid Output = 0.0507 (5.1%) -> Prediction: NOT SPAM
# Email 263: Sigmoid Output = 0.0754 (7.5%) -> Prediction: NOT SPAM
# Email 264: Sigmoid Output = 0.0433 (4.3%) -> Prediction: NOT SPAM
# Email 265: Sigmoid Output = 0.0500 (5.0%) -> Prediction: NOT SPAM
# Email 266: Sigmoid Output = 0.0514 (5.1%) -> Prediction: NOT SPAM
# Email 267: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 268: Sigmoid Output = 0.7587 (75.9%) -> Prediction: SPAM
# Email 269: Sigmoid Output = 0.0449 (4.5%) -> Prediction: NOT SPAM
# Email 270: Sigmoid Output = 0.0524 (5.2%) -> Prediction: NOT SPAM
# Email 271: Sigmoid Output = 0.0663 (6.6%) -> Prediction: NOT SPAM
# Email 272: Sigmoid Output = 0.0847 (8.5%) -> Prediction: NOT SPAM
# Email 273: Sigmoid Output = 0.0664 (6.6%) -> Prediction: NOT SPAM
# Email 274: Sigmoid Output = 0.1144 (11.4%) -> Prediction: NOT SPAM
# Email 275: Sigmoid Output = 0.0507 (5.1%) -> Prediction: NOT SPAM
# Email 276: Sigmoid Output = 0.1004 (10.0%) -> Prediction: NOT SPAM
# Email 277: Sigmoid Output = 0.0572 (5.7%) -> Prediction: NOT SPAM
# Email 278: Sigmoid Output = 0.0667 (6.7%) -> Prediction: NOT SPAM
# Email 279: Sigmoid Output = 0.0910 (9.1%) -> Prediction: NOT SPAM
# Email 280: Sigmoid Output = 0.6759 (67.6%) -> Prediction: SPAM
# Email 281: Sigmoid Output = 0.0642 (6.4%) -> Prediction: NOT SPAM
# Email 282: Sigmoid Output = 0.0454 (4.5%) -> Prediction: NOT SPAM
# Email 283: Sigmoid Output = 0.0314 (3.1%) -> Prediction: NOT SPAM
# Email 284: Sigmoid Output = 0.0605 (6.0%) -> Prediction: NOT SPAM
# Email 285: Sigmoid Output = 0.6667 (66.7%) -> Prediction: SPAM
# Email 286: Sigmoid Output = 0.6363 (63.6%) -> Prediction: SPAM
# Email 287: Sigmoid Output = 0.0759 (7.6%) -> Prediction: NOT SPAM
# Email 288: Sigmoid Output = 0.0681 (6.8%) -> Prediction: NOT SPAM
# Email 289: Sigmoid Output = 0.0733 (7.3%) -> Prediction: NOT SPAM
# Email 290: Sigmoid Output = 0.0953 (9.5%) -> Prediction: NOT SPAM
# Email 291: Sigmoid Output = 0.0524 (5.2%) -> Prediction: NOT SPAM
# Email 292: Sigmoid Output = 0.4005 (40.1%) -> Prediction: NOT SPAM
# Email 293: Sigmoid Output = 0.3518 (35.2%) -> Prediction: NOT SPAM
# Email 294: Sigmoid Output = 0.0594 (5.9%) -> Prediction: NOT SPAM
# Email 295: Sigmoid Output = 0.0659 (6.6%) -> Prediction: NOT SPAM
# Email 296: Sigmoid Output = 0.0493 (4.9%) -> Prediction: NOT SPAM
# Email 297: Sigmoid Output = 0.0261 (2.6%) -> Prediction: NOT SPAM
# Email 298: Sigmoid Output = 0.1557 (15.6%) -> Prediction: NOT SPAM
# Email 299: Sigmoid Output = 0.2076 (20.8%) -> Prediction: NOT SPAM
# Email 300: Sigmoid Output = 0.0622 (6.2%) -> Prediction: NOT SPAM
# Email 301: Sigmoid Output = 0.0452 (4.5%) -> Prediction: NOT SPAM
# Email 302: Sigmoid Output = 0.0529 (5.3%) -> Prediction: NOT SPAM
# Email 303: Sigmoid Output = 0.0897 (9.0%) -> Prediction: NOT SPAM
# Email 304: Sigmoid Output = 0.0774 (7.7%) -> Prediction: NOT SPAM
# Email 305: Sigmoid Output = 0.1676 (16.8%) -> Prediction: NOT SPAM
# Email 306: Sigmoid Output = 0.0524 (5.2%) -> Prediction: NOT SPAM
# Email 307: Sigmoid Output = 0.0640 (6.4%) -> Prediction: NOT SPAM
# Email 308: Sigmoid Output = 0.0392 (3.9%) -> Prediction: NOT SPAM
# Email 309: Sigmoid Output = 0.0676 (6.8%) -> Prediction: NOT SPAM
# Email 310: Sigmoid Output = 0.0670 (6.7%) -> Prediction: NOT SPAM
# Email 311: Sigmoid Output = 0.0792 (7.9%) -> Prediction: NOT SPAM
# Email 312: Sigmoid Output = 0.0480 (4.8%) -> Prediction: NOT SPAM
# Email 313: Sigmoid Output = 0.0339 (3.4%) -> Prediction: NOT SPAM
# Email 314: Sigmoid Output = 0.0982 (9.8%) -> Prediction: NOT SPAM
# Email 315: Sigmoid Output = 0.2470 (24.7%) -> Prediction: NOT SPAM
# Email 316: Sigmoid Output = 0.3618 (36.2%) -> Prediction: NOT SPAM
# Email 317: Sigmoid Output = 0.0878 (8.8%) -> Prediction: NOT SPAM
# Email 318: Sigmoid Output = 0.0453 (4.5%) -> Prediction: NOT SPAM
# Email 319: Sigmoid Output = 0.0889 (8.9%) -> Prediction: NOT SPAM
# Email 320: Sigmoid Output = 0.3519 (35.2%) -> Prediction: NOT SPAM
# Email 321: Sigmoid Output = 0.0828 (8.3%) -> Prediction: NOT SPAM
# Email 322: Sigmoid Output = 0.1283 (12.8%) -> Prediction: NOT SPAM
# Email 323: Sigmoid Output = 0.0764 (7.6%) -> Prediction: NOT SPAM
# Email 324: Sigmoid Output = 0.0433 (4.3%) -> Prediction: NOT SPAM
# Email 325: Sigmoid Output = 0.1657 (16.6%) -> Prediction: NOT SPAM
# Email 326: Sigmoid Output = 0.1219 (12.2%) -> Prediction: NOT SPAM
# Email 327: Sigmoid Output = 0.7221 (72.2%) -> Prediction: SPAM
# Email 328: Sigmoid Output = 0.1022 (10.2%) -> Prediction: NOT SPAM
# Email 329: Sigmoid Output = 0.0482 (4.8%) -> Prediction: NOT SPAM
# Email 330: Sigmoid Output = 0.0845 (8.5%) -> Prediction: NOT SPAM
# Email 331: Sigmoid Output = 0.0577 (5.8%) -> Prediction: NOT SPAM
# Email 332: Sigmoid Output = 0.0623 (6.2%) -> Prediction: NOT SPAM
# Email 333: Sigmoid Output = 0.0501 (5.0%) -> Prediction: NOT SPAM
# Email 334: Sigmoid Output = 0.0410 (4.1%) -> Prediction: NOT SPAM
# Email 335: Sigmoid Output = 0.0888 (8.9%) -> Prediction: NOT SPAM
# Email 336: Sigmoid Output = 0.0441 (4.4%) -> Prediction: NOT SPAM
# Email 337: Sigmoid Output = 0.6033 (60.3%) -> Prediction: SPAM
# Email 338: Sigmoid Output = 0.0440 (4.4%) -> Prediction: NOT SPAM
# Email 339: Sigmoid Output = 0.0841 (8.4%) -> Prediction: NOT SPAM
# Email 340: Sigmoid Output = 0.0806 (8.1%) -> Prediction: NOT SPAM
# Email 341: Sigmoid Output = 0.0572 (5.7%) -> Prediction: NOT SPAM
# Email 342: Sigmoid Output = 0.0746 (7.5%) -> Prediction: NOT SPAM
# Email 343: Sigmoid Output = 0.0689 (6.9%) -> Prediction: NOT SPAM
# Email 344: Sigmoid Output = 0.0876 (8.8%) -> Prediction: NOT SPAM
# Email 345: Sigmoid Output = 0.0877 (8.8%) -> Prediction: NOT SPAM
# Email 346: Sigmoid Output = 0.0581 (5.8%) -> Prediction: NOT SPAM
# Email 347: Sigmoid Output = 0.7765 (77.6%) -> Prediction: SPAM
# Email 348: Sigmoid Output = 0.0465 (4.6%) -> Prediction: NOT SPAM
# Email 349: Sigmoid Output = 0.1710 (17.1%) -> Prediction: NOT SPAM
# Email 350: Sigmoid Output = 0.5934 (59.3%) -> Prediction: SPAM
# Email 351: Sigmoid Output = 0.0631 (6.3%) -> Prediction: NOT SPAM
# Email 352: Sigmoid Output = 0.0948 (9.5%) -> Prediction: NOT SPAM
# Email 353: Sigmoid Output = 0.0653 (6.5%) -> Prediction: NOT SPAM
# Email 354: Sigmoid Output = 0.0485 (4.8%) -> Prediction: NOT SPAM
# Email 355: Sigmoid Output = 0.0589 (5.9%) -> Prediction: NOT SPAM
# Email 356: Sigmoid Output = 0.1080 (10.8%) -> Prediction: NOT SPAM
# Email 357: Sigmoid Output = 0.0498 (5.0%) -> Prediction: NOT SPAM
# Email 358: Sigmoid Output = 0.3202 (32.0%) -> Prediction: NOT SPAM
# Email 359: Sigmoid Output = 0.0515 (5.2%) -> Prediction: NOT SPAM
# Email 360: Sigmoid Output = 0.0773 (7.7%) -> Prediction: NOT SPAM
# Email 361: Sigmoid Output = 0.0532 (5.3%) -> Prediction: NOT SPAM
# Email 362: Sigmoid Output = 0.0703 (7.0%) -> Prediction: NOT SPAM
# Email 363: Sigmoid Output = 0.1567 (15.7%) -> Prediction: NOT SPAM
# Email 364: Sigmoid Output = 0.0579 (5.8%) -> Prediction: NOT SPAM
# Email 365: Sigmoid Output = 0.0224 (2.2%) -> Prediction: NOT SPAM
# Email 366: Sigmoid Output = 0.0669 (6.7%) -> Prediction: NOT SPAM
# Email 367: Sigmoid Output = 0.0793 (7.9%) -> Prediction: NOT SPAM
# Email 368: Sigmoid Output = 0.0723 (7.2%) -> Prediction: NOT SPAM
# Email 369: Sigmoid Output = 0.0407 (4.1%) -> Prediction: NOT SPAM
# Email 370: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 371: Sigmoid Output = 0.0750 (7.5%) -> Prediction: NOT SPAM
# Email 372: Sigmoid Output = 0.8594 (85.9%) -> Prediction: SPAM
# Email 373: Sigmoid Output = 0.0660 (6.6%) -> Prediction: NOT SPAM
# Email 374: Sigmoid Output = 0.4276 (42.8%) -> Prediction: NOT SPAM
# Email 375: Sigmoid Output = 0.3937 (39.4%) -> Prediction: NOT SPAM
# Email 376: Sigmoid Output = 0.0533 (5.3%) -> Prediction: NOT SPAM
# Email 377: Sigmoid Output = 0.0297 (3.0%) -> Prediction: NOT SPAM
# Email 378: Sigmoid Output = 0.0647 (6.5%) -> Prediction: NOT SPAM
# Email 379: Sigmoid Output = 0.0656 (6.6%) -> Prediction: NOT SPAM
# Email 380: Sigmoid Output = 0.0435 (4.3%) -> Prediction: NOT SPAM
# Email 381: Sigmoid Output = 0.3889 (38.9%) -> Prediction: NOT SPAM
# Email 382: Sigmoid Output = 0.0879 (8.8%) -> Prediction: NOT SPAM
# Email 383: Sigmoid Output = 0.0698 (7.0%) -> Prediction: NOT SPAM
# Email 384: Sigmoid Output = 0.1238 (12.4%) -> Prediction: NOT SPAM
# Email 385: Sigmoid Output = 0.0499 (5.0%) -> Prediction: NOT SPAM
# Email 386: Sigmoid Output = 0.0548 (5.5%) -> Prediction: NOT SPAM
# Email 387: Sigmoid Output = 0.2316 (23.2%) -> Prediction: NOT SPAM
# Email 388: Sigmoid Output = 0.0973 (9.7%) -> Prediction: NOT SPAM
# Email 389: Sigmoid Output = 0.3421 (34.2%) -> Prediction: NOT SPAM
# Email 390: Sigmoid Output = 0.0506 (5.1%) -> Prediction: NOT SPAM
# Email 391: Sigmoid Output = 0.4410 (44.1%) -> Prediction: NOT SPAM
# Email 392: Sigmoid Output = 0.0588 (5.9%) -> Prediction: NOT SPAM
# Email 393: Sigmoid Output = 0.0531 (5.3%) -> Prediction: NOT SPAM
# Email 394: Sigmoid Output = 0.4317 (43.2%) -> Prediction: NOT SPAM
# Email 395: Sigmoid Output = 0.0467 (4.7%) -> Prediction: NOT SPAM
# Email 396: Sigmoid Output = 0.0462 (4.6%) -> Prediction: NOT SPAM
# Email 397: Sigmoid Output = 0.3252 (32.5%) -> Prediction: NOT SPAM
# Email 398: Sigmoid Output = 0.0596 (6.0%) -> Prediction: NOT SPAM
# Email 399: Sigmoid Output = 0.1338 (13.4%) -> Prediction: NOT SPAM
# Email 400: Sigmoid Output = 0.1077 (10.8%) -> Prediction: NOT SPAM

# %%
print("\n" + "="*60 + "\nSample test message, true label, spam-probability:\n")
for i in range(5):
    msg = sample_messages.iloc[i]
    true_label = "SPAM" if y_test.reset_index(drop=True).iloc[i]==1 else "NOT SPAM"
    spam_prob = probabilities[i][1]
    print(f"Message {i+1} (True: {true_label}, Prob(spam)={spam_prob:.3f}):\n  {msg}\n")
# Out:
# ============================================================
# Sample test message, true label, spam-probability:
#
# Message 1 (True: NOT SPAM, Prob(spam)=0.069):
#   Thanx 4 sending me home...
#
# Message 2 (True: NOT SPAM, Prob(spam)=0.078):
#   Then i buy.
#
# Message 3 (True: NOT SPAM, Prob(spam)=0.051):
#   His frens go then he in lor. Not alone wif my mum n sis lor.
#
# Message 4 (True: NOT SPAM, Prob(spam)=0.076):
#   What year. And how many miles.
#
# Message 5 (True: NOT SPAM, Prob(spam)=0.073):
#   What can i do? Might accidant tookplace between somewhere ghodbandar rd. Traffic moves slovely. So plz slip &amp; don't worry.
